# %% [markdown]
# # student_mark prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(pd.read_csv(r"I:\MLpratice\student_mark.csv"))

# %%
df.head()
# Out:
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   NaN   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   NaN   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   NaN   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   NaN   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   NaN   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
df.tail()
# Out:
#       1st   2nd   3rd   4th   5th  College Code Gender     Roll  Roll no.  \
# 173  7.48  7.55  7.67  7.39  8.65           241      F  17048.0       NaN
# 174  7.30  6.41  6.59  7.11  7.38           241      M  17049.0       NaN
# 175  6.30  6.28  5.89  5.71  6.50           241      M  17050.0       NaN
# 176  7.04  7.10  6.81  7.00  6.92           241      M  17051.0       NaN
# 177  6.70  6.81  6.52  5.39  7.00           241      M  17052.0       NaN
#
#      Subject Code
# 173            28
# 174            28
# 175            28
# 176            28
# 177            28

# %%
df.shape
# Out:
# (178, 10)

# %%
df.describe()
# Out:
#               1st         2nd        3rd         4th         5th  \
# count  176.000000  174.000000  176.00000  173.000000  172.000000
# mean     7.038864    6.943391    6.62250    7.027746    7.432558
# std      0.859521    0.881088    0.91926    1.035675    1.068866
# min      3.850000    3.900000    3.96000    4.290000    4.000000
# 25%      6.440000    6.380000    6.14000    6.330000    6.750000
# 50%      7.070000    6.800000    6.68500    7.070000    7.590000
# 75%      7.590000    7.612500    7.26000    7.860000    8.210000
# max      9.150000    9.210000    9.59000    9.310000    9.460000
#
#        College Code          Roll      Roll no.  Subject Code
# count    178.000000    132.000000     46.000000    178.000000
# mean     152.983146  17040.666667  17042.500000     18.359551
# std       48.357599     13.622874     13.422618      4.782849
# min      115.000000  17017.000000  17020.000000     16.000000
# 25%      115.000000  17029.000000  17031.250000     16.000000
# ...

# %%
df.isnull().sum()
# Out:
# 1st               2
# 2nd               4
# 3rd               2
# 4th               5
# 5th               6
# College Code      0
# Gender            1
# Roll             46
# Roll no.        132
# Subject Code      0
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels= False , cbar= False)
# Out:
# <AxesSubplot: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1st           176 non-null    float64
#  1   2nd           174 non-null    float64
#  2   3rd           176 non-null    float64
#  3   4th           173 non-null    float64
#  4   5th           172 non-null    float64
#  5   College Code  178 non-null    int64
#  6   Gender        177 non-null    object
#  7   Roll          132 non-null    float64
#  8   Roll no.      46 non-null     float64
#  9   Subject Code  178 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 14.0+ KB

# %% [markdown]
# We can see there is a column name Gender which doesn't have int or float values. So, I want to see that data.

# %%
df['Gender']
# Out:
# 0      Female
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 173         F
# 174         M
# 175         M
# 176         M
# 177         M
# Name: Gender, Length: 178, dtype: object

# %% [markdown]
# There are some values that are Female and Some are Male and others are F and M. So in it we have to make similar values like F for female and M for Male.

# %%
df["Gender"].replace({'Female':'F','Male':'M'}, inplace = True)

# %%
df['Gender']
# Out:
# 0      F
# 1      M
# 2      F
# 3      M
# 4      M
#       ..
# 173    F
# 174    M
# 175    M
# 176    M
# 177    M
# Name: Gender, Length: 178, dtype: object

# %%
df
# Out:
#       1st   2nd   3rd   4th   5th  College Code Gender     Roll  Roll no.  \
# 0    8.11  7.68  7.11  7.43  8.18           115      F      NaN   17020.0
# 1    6.48  5.90  4.15  4.29  4.96           115      M      NaN   17021.0
# 2    8.41  8.24  7.52  8.25  7.75           115      F      NaN   17022.0
# 3    7.33  6.83  6.33  6.79  6.89           115      M      NaN   17023.0
# 4    7.89  7.34  7.22  7.32  7.46           115      M      NaN   17024.0
# ..    ...   ...   ...   ...   ...           ...    ...      ...       ...
# 173  7.48  7.55  7.67  7.39  8.65           241      F  17048.0       NaN
# 174  7.30  6.41  6.59  7.11  7.38           241      M  17049.0       NaN
# 175  6.30  6.28  5.89  5.71  6.50           241      M  17050.0       NaN
# 176  7.04  7.10  6.81  7.00  6.92           241      M  17051.0       NaN
# 177  6.70  6.81  6.52  5.39  7.00           241      M  17052.0       NaN
#
#      Subject Code
# 0              16
# 1              16
# 2              16
# ...

# %%
#check null values for some columns

df['College Code'].value_counts()
# Out:
# 116    51
# 115    46
# 165    46
# 241    35
# Name: College Code, dtype: int64

# %%
df["Subject Code"].value_counts()
# Out:
# 16    143
# 28     35
# Name: Subject Code, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# M    149
# F     28
# Name: Gender, dtype: int64

# %%
df
# Out:
#       1st   2nd   3rd   4th   5th  College Code Gender     Roll  Roll no.  \
# 0    8.11  7.68  7.11  7.43  8.18           115      F      NaN   17020.0
# 1    6.48  5.90  4.15  4.29  4.96           115      M      NaN   17021.0
# 2    8.41  8.24  7.52  8.25  7.75           115      F      NaN   17022.0
# 3    7.33  6.83  6.33  6.79  6.89           115      M      NaN   17023.0
# 4    7.89  7.34  7.22  7.32  7.46           115      M      NaN   17024.0
# ..    ...   ...   ...   ...   ...           ...    ...      ...       ...
# 173  7.48  7.55  7.67  7.39  8.65           241      F  17048.0       NaN
# 174  7.30  6.41  6.59  7.11  7.38           241      M  17049.0       NaN
# 175  6.30  6.28  5.89  5.71  6.50           241      M  17050.0       NaN
# 176  7.04  7.10  6.81  7.00  6.92           241      M  17051.0       NaN
# 177  6.70  6.81  6.52  5.39  7.00           241      M  17052.0       NaN
#
#      Subject Code
# 0              16
# 1              16
# 2              16
# ...

# %%
# 1.We can see that there are NaN values in the Roll Number Column.
#2. make Roll No values in the Int type


 #Replacing Null values from 0

# %%
df['Roll'].fillna(0,inplace = True)

df["Roll no."].fillna(0, inplace = True)

# %%
#combining two columns into one. 

df['Roll_No'] = df["Roll"] + df["Roll no."]

# %%
df.drop(["Roll", "Roll no."],axis = 1, inplace = True)

# %%
df['Roll_No'].astype(int)
# Out:
# 0      17020
# 1      17021
# 2      17022
# 3      17023
# 4      17024
#        ...
# 173    17048
# 174    17049
# 175    17050
# 176    17051
# 177    17052
# Name: Roll_No, Length: 178, dtype: int32

# %%
df
# Out:
#       1st   2nd   3rd   4th   5th  College Code Gender  Subject Code  Roll_No
# 0    8.11  7.68  7.11  7.43  8.18           115      F            16  17020.0
# 1    6.48  5.90  4.15  4.29  4.96           115      M            16  17021.0
# 2    8.41  8.24  7.52  8.25  7.75           115      F            16  17022.0
# 3    7.33  6.83  6.33  6.79  6.89           115      M            16  17023.0
# 4    7.89  7.34  7.22  7.32  7.46           115      M            16  17024.0
# ..    ...   ...   ...   ...   ...           ...    ...           ...      ...
# 173  7.48  7.55  7.67  7.39  8.65           241      F            28  17048.0
# 174  7.30  6.41  6.59  7.11  7.38           241      M            28  17049.0
# 175  6.30  6.28  5.89  5.71  6.50           241      M            28  17050.0
# 176  7.04  7.10  6.81  7.00  6.92           241      M            28  17051.0
# 177  6.70  6.81  6.52  5.39  7.00           241      M            28  17052.0
#
# [178 rows x 9 columns]

# %%
#checking missing values

df.isnull().sum()
# Out:
# 1st             2
# 2nd             4
# 3rd             2
# 4th             5
# 5th             6
# College Code    0
# Gender          1
# Subject Code    0
# Roll_No         0
# dtype: int64

# %% [markdown]
# There are some Null values in the Data also.

# %%
#fill missing values


df['1st'].fillna(df['1st'].mean(),inplace = True) 
df['2nd'].fillna(df['2nd'].mean(),inplace = True)
df['3rd'].fillna(df['3rd'].mean(),inplace= True)
df['4th'].fillna(df['4th'].mean(),inplace= True)
df['5th'].fillna(df['5th'].mean(),inplace= True)
df['Gender'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# 1st             0
# 2nd             0
# 3rd             0
# 4th             0
# 5th             0
# College Code    0
# Gender          0
# Subject Code    0
# Roll_No         0
# dtype: int64

# %% [markdown]
# # We can combine College Code, Subject Code and Roll_no Column together

# %%
df['College Code']=df['College Code'].astype(str)
df['Subject Code']=df['Subject Code'].astype(str)
df['Roll_No']=df['Roll_No'].astype(str)

# %%
df['studentid']=df['College Code']+df['Subject Code']+df['Roll_No']
df['studentid']
# Out:
# 0      1151617020.0
# 1      1151617021.0
# 2      1151617022.0
# 3      1151617023.0
# 4      1151617024.0
#            ...
# 173    2412817048.0
# 174    2412817049.0
# 175    2412817050.0
# 176    2412817051.0
# 177    2412817052.0
# Name: studentid, Length: 178, dtype: object

# %%
df.drop(["College Code","Subject Code","Roll_No"],axis = 1 , inplace = True)

# %%
df
# Out:
#       1st   2nd   3rd   4th   5th Gender     studentid
# 0    8.11  7.68  7.11  7.43  8.18      F  1151617020.0
# 1    6.48  5.90  4.15  4.29  4.96      M  1151617021.0
# 2    8.41  8.24  7.52  8.25  7.75      F  1151617022.0
# 3    7.33  6.83  6.33  6.79  6.89      M  1151617023.0
# 4    7.89  7.34  7.22  7.32  7.46      M  1151617024.0
# ..    ...   ...   ...   ...   ...    ...           ...
# 173  7.48  7.55  7.67  7.39  8.65      F  2412817048.0
# 174  7.30  6.41  6.59  7.11  7.38      M  2412817049.0
# 175  6.30  6.28  5.89  5.71  6.50      M  2412817050.0
# 176  7.04  7.10  6.81  7.00  6.92      M  2412817051.0
# 177  6.70  6.81  6.52  5.39  7.00      M  2412817052.0
#
# [178 rows x 7 columns]

# %% [markdown]
# # to find a variable that have relationship with the 1st, 2nd, 3rd, 4th and 5th Column.

# %%
df['res'] = (df['1st'])+(df['2nd'])+(df['3rd'])+(df['4th'])+(df['5th'])

# %%
#correealtion

df.corr()
# Out:
#           1st       2nd       3rd       4th       5th       res
# 1st  1.000000  0.743298  0.732211  0.675402  0.673390  0.847963
# 2nd  0.743298  1.000000  0.761735  0.728502  0.732602  0.883043
# 3rd  0.732211  0.761735  1.000000  0.811949  0.766755  0.911996
# 4th  0.675402  0.728502  0.811949  1.000000  0.821355  0.911987
# 5th  0.673390  0.732602  0.766755  0.821355  1.000000  0.903869
# res  0.847963  0.883043  0.911996  0.911987  0.903869  1.000000

# %%
#pair plot of correlation

sns.heatmap(df1.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
df
# Out:
#       1st   2nd   3rd   4th   5th Gender     studentid    res
# 0    8.11  7.68  7.11  7.43  8.18      F  1151617020.0  38.51
# 1    6.48  5.90  4.15  4.29  4.96      M  1151617021.0  25.78
# 2    8.41  8.24  7.52  8.25  7.75      F  1151617022.0  40.17
# 3    7.33  6.83  6.33  6.79  6.89      M  1151617023.0  34.17
# 4    7.89  7.34  7.22  7.32  7.46      M  1151617024.0  37.23
# ..    ...   ...   ...   ...   ...    ...           ...    ...
# 173  7.48  7.55  7.67  7.39  8.65      F  2412817048.0  38.74
# 174  7.30  6.41  6.59  7.11  7.38      M  2412817049.0  34.79
# 175  6.30  6.28  5.89  5.71  6.50      M  2412817050.0  30.68
# 176  7.04  7.10  6.81  7.00  6.92      M  2412817051.0  34.87
# 177  6.70  6.81  6.52  5.39  7.00      M  2412817052.0  32.42
#
# [178 rows x 8 columns]

# %% [markdown]
# Select only relevent columns only.¶

# %%
df1 = df[['1st','2nd', '3rd', '4th','5th','res']]

# %%
df1
# Out:
#       1st   2nd   3rd   4th   5th    res
# 0    8.11  7.68  7.11  7.43  8.18  38.51
# 1    6.48  5.90  4.15  4.29  4.96  25.78
# 2    8.41  8.24  7.52  8.25  7.75  40.17
# 3    7.33  6.83  6.33  6.79  6.89  34.17
# 4    7.89  7.34  7.22  7.32  7.46  37.23
# ..    ...   ...   ...   ...   ...    ...
# 173  7.48  7.55  7.67  7.39  8.65  38.74
# 174  7.30  6.41  6.59  7.11  7.38  34.79
# 175  6.30  6.28  5.89  5.71  6.50  30.68
# 176  7.04  7.10  6.81  7.00  6.92  34.87
# 177  6.70  6.81  6.52  5.39  7.00  32.42
#
# [178 rows x 6 columns]

# %%
## Independent features and dependent features
x = df1.drop(["res"],axis=1)
y = df1.res

# %%
from sklearn. model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y,random_state= 0, test_size = 0.2)

# %%
x
# Out:
#       1st   2nd   3rd   4th   5th
# 0    8.11  7.68  7.11  7.43  8.18
# 1    6.48  5.90  4.15  4.29  4.96
# 2    8.41  8.24  7.52  8.25  7.75
# 3    7.33  6.83  6.33  6.79  6.89
# 4    7.89  7.34  7.22  7.32  7.46
# ..    ...   ...   ...   ...   ...
# 173  7.48  7.55  7.67  7.39  8.65
# 174  7.30  6.41  6.59  7.11  7.38
# 175  6.30  6.28  5.89  5.71  6.50
# 176  7.04  7.10  6.81  7.00  6.92
# 177  6.70  6.81  6.52  5.39  7.00
#
# [178 rows x 5 columns]

# %%
y
# Out:
# 0      38.51
# 1      25.78
# 2      40.17
# 3      34.17
# 4      37.23
#        ...
# 173    38.74
# 174    34.79
# 175    30.68
# 176    34.87
# 177    32.42
# Name: res, Length: 178, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
y_pred = regr.predict(X_train)

# %%
##cross validation
from sklearn.model_selection import cross_val_score

# %%
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=y_pred)))
# Out:
# R squared: 1.0

# %%
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 5.4791851806852794e-15

# %%
sns.displot(reg_pred-y_test,kind='kde')

# %%
# cheaking using another algo
from sklearn.tree import DecisionTreeRegressor

dec_tree = DecisionTreeRegressor(random_state=0)
dec_tree.fit(X_train,y_train)
dec_tree_y_pred = dec_tree.predict(X_train)
print("Accuracy: {}".format(dec_tree.score(X_train,y_train)))
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=dec_tree_y_pred)))
# Out:
# Accuracy: 1.0
# R squared: 1.0

# %%
from sklearn.ensemble import RandomForestRegressor

rf_tree = RandomForestRegressor(random_state=0)
rf_tree.fit(X_train,y_train)
rf_tree_y_pred = rf_tree.predict(X_train)
print("Accuracy: {}".format(rf_tree.score(X_train,y_train)))
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=rf_tree_y_pred)))
# Out:
# Accuracy: 0.9967167837277959
# R squared: 0.9967167837277959
